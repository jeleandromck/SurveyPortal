# %%
# !pip install xlsxwriter -q

# %%
# %load_ext autoreload
# %autoreload 2
    
# %matplotlib inline

#basic data analysis libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pylab as plt
import seaborn as sns

import os, glob
import re
from tqdm import tqdm

from IPython.display  import HTML

# %config InlineBackend.figure_format='retina'
np.set_printoptions(precision=4)
pd.options.display.max_rows = 999
pd.options.display.float_format = '{:,.3f}'.format
sns.set_style("whitegrid")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def drop_cols(df, cols_to_drop):
    cols_to_drop = [c for c in cols_to_drop if c in df.columns];
    if len(cols_to_drop)>0:
        df.drop(columns=cols_to_drop, inplace=True);
    print(f'Colunas atuais {len(df.columns):<4} - Colunas Removidas {len(cols_to_drop):<4}')
    return df;

# %%
def filterCols(df, subs):
    cols = [c for c in df.columns if subs in c];
    return df[cols]

# %%
df_pesquisa = (
    pd.read_excel('../data/k24069946_240627_102351_-03.xlsx')
)

# %% [markdown]
# ## Removendo colunas não uteis ou com preenchimento constante ou que sejam de controle

# %%
colunas_removidas = []

# %%
# removendo colunas 100% em branco
miss100 = df_pesquisa.isna().mean().to_frame('pmiss').query('pmiss ==1').index.tolist()
df_pesquisa.pipe(drop_cols,miss100)

colunas_removidas += [ (c,'100% vazia') for c in miss100]
# Out:
# Colunas atuais 1744 - Colunas Removidas 741

# %%
# Removendo colunas com valores contantes
valores_unicos_1 = df_pesquisa.nunique().to_frame('valores_unicos').query('valores_unicos ==1').index.tolist()
df_pesquisa.pipe(drop_cols,valores_unicos_1)
colunas_removidas += [ (c,'Valores constantes') for c in valores_unicos_1]
# Out:
# Colunas atuais 986  - Colunas Removidas 758

# %%
# removendo colunas de controle para preenchimento de cotas da pesquisa
cota_cols  = [c for c in df_pesquisa.columns.tolist() if 'QGEN_AGE_QTA' in c or 'QCURRENT_QTA' in c or 'QSPRINCIPAL_QTA' in c] 
cota_cols += ['QREGION_QTA','QSINC_QTA']
df_pesquisa.pipe(drop_cols,cota_cols)
colunas_removidas += [ (c,'flags cotas') for c in cota_cols]
# Out:
# Colunas atuais 909  - Colunas Removidas 77

# %%
cota_cols = [c for c in df_pesquisa.columns.tolist() if 'QCOUNTRY_GENAGE' in c or 'QBANKED_DEFAULTER' in c or 'QCOUNTRY_X_DEFAULTER' in c]
df_pesquisa.pipe(drop_cols,cota_cols)
colunas_removidas += [ (c,'flags cotas') for c in cota_cols]
# Out:
# Colunas atuais 880  - Colunas Removidas 29

# %%
# removendo colunas "outros" com baixo preenchimento
col_others = [c for c in df_pesquisa.columns.tolist() if ('QPRODUCT_' in c and 'OTH' in c) or 'QATTCHECKS' in c]
col_others += [
    'QDWORK_97_OTH','QSESCOL_97_OTH','Q30R97_OTH','Q34R97_OTH','Q25R97_OTH','Q44R97_OTH','Q45R97_OTH',
    'Q13.9','Q38.97','Q23_97_OTH','Q38_97_OTH','Q39.97','Q39_97_OTH','Q40.97','Q40_97_OTH',]
df_pesquisa.pipe(drop_cols,col_others)
colunas_removidas += [ (c,'Outros') for c in col_others]
# Out:
# Colunas atuais 844  - Colunas Removidas 36

# %%
colunas_extras  = ['resp_last_ts','QREV','QSAMP','QGENDER','QBANK_SAMP','QDEFAULTER_SAMP']
colunas_extras += ['tz_name', 'win_version','failed_attempts','QSURTM', 'QFEEDBACK_english_us','QAGEDIFF',
     'timezone','browser_version','screensize','device_type',]

df_pesquisa.pipe(drop_cols,colunas_extras)
colunas_removidas += [ (c,'Irrelevantes') for c in colunas_extras]
# Out:
# Colunas atuais 828  - Colunas Removidas 16

# %%
(
    pd.DataFrame(colunas_removidas, columns=['col','reason2remove'])
    .groupby('reason2remove')
    .count()
)
# Out:
#                     col
# reason2remove
# 100% vazia          741
# Irrelevantes         16
# Outros               37
# Valores constantes  758
# flags cotas         106

# %%
def moveColuns(df, cols_first=[], cols_last=[]):
    """"
    Reorder the coluns moving to the first position, some to the last and the rest in the middle
    """
    columns = df.columns;
    if len(cols_first)>1:
        cols_first = [c for c in columns if c in cols_first]

    if len(cols_last) > 1:
        cols_last = [c for c in columns if c in cols_last]

    others = [c for c in columns if c not in cols_first and c not in cols_last]

    return df[cols_first+others+cols_last];

# %%
def cleanBanc(row, others):
    """
        Alguns clientes preencheram que tem outros bancos porém na descrição eles listam bancos que deveria estar na lista.
        Essa funcao visa reduzir o número de outros
    """
    if row['QSPRINCIPAL'] < 500:
        return row['QSPRINCIPAL'];
    else:
        v = row[others]
        if type(v) != float:
            v = v.upper().strip()
            if v == 'NUBANK':return 222;
            elif 'SANTANDER' in v: return 226;
            elif 'ITA' in v: return 217;
            elif 'CAIXA' in v: return 211;
            elif 'BRADESCO' in v: return 207;
            elif 'ORIGINAL' in v: return 204;
            elif 'INTER' in v: return 216;
            elif 'BRASIL' in v: return 203;
            elif 'MERCADO' in v: return 219;
            elif 'PAG' in v and 'BANK' in v: return 223;
            elif 'NEON' in v: return 220;
            elif 'SICOOB' in v:return 227;
            elif 'SICRED' in v:return 228;
            elif 'PICPAY' in v:return 224;
    

    return 288;

# %%
def cleanFeedBack(df):
    """
        clean if the feedback has few words
    """
    df = df.copy()
    df['QFEEDBACK'] = df['QFEEDBACK'].apply(lambda x: x if type(x) == str and len(x.split())>5 else '' )
    return df;

# %% [markdown]
# # main loop

# %%
from mappings2 import *

depara_colunas = []
drop_after_processing = ['QSPRINCIPAL_971_OTH','QSPRINCIPAL_972_OTH','QSPRINCIPAL_973_OTH',]

renames_basicos = {
    'resp_start_ts':'data_resposta',
    'QSAGE':'idade',
    'QAGEMATH':'idade_calculada',
    'QAGE':'faixa_idade',
    'QDYEARBORN':'ano_nascimento',
    'Q13_97_OTH':'origem_dinheiro_pagamento_contas__outros',

}

for k,v in renames_basicos.items():
    depara_colunas.append([k,v])
    print(f"{k:<20} ==> {v}")

df_transf = (
    df_pesquisa
    .copy()
    .assign(resp_start_ts=lambda x:x['resp_start_ts'].dt.date)
    .assign(QSPRINCIPAL=lambda x:x[['QSPRINCIPAL','QSPRINCIPAL_971_OTH']].apply(cleanBanc,others='QSPRINCIPAL_971_OTH', axis=1))
    .assign(QSPRINCIPAL=lambda x:x[['QSPRINCIPAL','QSPRINCIPAL_972_OTH']].apply(cleanBanc,others='QSPRINCIPAL_972_OTH', axis=1))
    .assign(QSPRINCIPAL=lambda x:x[['QSPRINCIPAL','QSPRINCIPAL_973_OTH']].apply(cleanBanc,others='QSPRINCIPAL_973_OTH', axis=1))

    .pipe(cleanFeedBack)
    .rename(columns=renames_basicos)
    .drop(columns=drop_after_processing)
)

for map_ in mapeamento:
    col = map_['col']
    rename= map_['rename']
    map = map_['map']
    depara_colunas.append([col, rename])
    print(f"{col:<20} ==> {rename}")

    if col not in df_transf.columns:
        print(f"+{col} não encontrada.")
        #print(map_)
        continue;
        

    df_transf = (
        df_transf
        .rename(columns={col:rename})
        .assign(**{
            rename:lambda df: df[rename].map(map)
        })
    )


df_transf=df_transf.pipe(moveColuns,cols_first=[
    'id','data_resposta','elapsed','genero','idade','idade_calculada','faixa_idade','ano_nascimento','escolaridade','estado_civil',
    'estado','regiao','capital','tipo_emprego',
    'banco_principal','default','default_detalhe',
    'cartao_loja','consistencia_pagamento_cartao','comprometimento_renda_com_parcelas',
    'perspectiva_futuro','nivel_suporte_contratacao', 'transparencia_comunicacao',
], cols_last=['QFEEDBACK','QATT1R88','Q13.97','Q13_97_OTH','Q44R97_OTH','Q45R97_OTH','Q26R88'])
# Out:
# resp_start_ts        ==> data_resposta
# QSAGE                ==> idade
# QAGEMATH             ==> idade_calculada
# QAGE                 ==> faixa_idade
# QDYEARBORN           ==> ano_nascimento
# Q13_97_OTH           ==> origem_dinheiro_pagamento_contas__outros
# QSGEND               ==> genero
# QSSTATE              ==> estado
# QREGION              ==> regiao
# QSCAPITAL            ==> capital
# QDMARITAL            ==> estado_civil
# QSINC                ==> faixa_renda
# QSESCOL              ==> escolaridade
# QDWORK               ==> tipo_emprego
# QNB0                 ==> bancarizado_uso_conta
# QBANKED              ==> ind_bancarizado
# QNB1                 ==> cartao_loja
# QSPRINCIPAL          ==> banco_principal
# QDEFAULTER           ==> default
# QINA                 ==> default_detalhe
# QFUT                 ==> perspectiva_futuro
# Q19                  ==> nivel_suporte_contratacao
# Q48                  ==> transparencia_comunicacao
# Q27                  ==> uso_limite_conta_corr_12_meses
# Q29                  ==> consistencia_pagamento_cartao
# Q35                  ==> comprometimento_renda_com_parcelas
# Q50                  ==> credito_parcelado__aceito_outros_parcelamentos_alem_do_cartao
# Q36                  ==> valor_em_atraso
# Q37                  ==> meses_inadimplentes
# Q47                  ==> prazo_pretende_quitar
# Q18RANK1             ==> canal_contratacao_prioridade__1
# Q18RANK2             ==> canal_contratacao_prioridade__2
# Q18RANK3             ==> canal_contratacao_prioridade__3
# Q18RANK4             ==> canal_contratacao_prioridade__4
# Q18RANK5             ==> canal_contratacao_prioridade__5
# Q30RANK1             ==> cartao_credito_novo__importancia__1
# Q30RANK2             ==> cartao_credito_novo__importancia__2
# Q30RANK3             ==> cartao_credito_novo__importancia__3
# Q30RANK4             ==> cartao_credito_novo__importancia__4
# Q30RANK5             ==> cartao_credito_novo__importancia__5
# Q34RANK1             ==> credito_parcelado_novo__importancia__1
# Q34RANK2             ==> credito_parcelado_novo__importancia__2
# Q34RANK3             ==> credito_parcelado_novo__importancia__3
# Q34RANK4             ==> credito_parcelado_novo__importancia__4
# Q34RANK5             ==> credito_parcelado_novo__importancia__5
# Q41RANK1             ==> inadimplencia__melhor_forma_de_saber__1
# Q41RANK2             ==> inadimplencia__melhor_forma_de_saber__2
# Q41RANK3             ==> inadimplencia__melhor_forma_de_saber__3
# Q41RANK4             ==> inadimplencia__melhor_forma_de_saber__4
# Q41RANK5             ==> inadimplencia__melhor_forma_de_saber__5
# Q44RANK1             ==> melhorias_processo_cobranca__1
# Q44RANK2             ==> melhorias_processo_cobranca__2
# Q44RANK3             ==> melhorias_processo_cobranca__3
# Q44RANK4             ==> melhorias_processo_cobranca__4
# Q44RANK5             ==> melhorias_processo_cobranca__5
# Q45RANK1             ==> tipo_ofertas_renegociacao__1
# Q45RANK2             ==> tipo_ofertas_renegociacao__2
# Q45RANK3             ==> tipo_ofertas_renegociacao__3
# Q45RANK4             ==> tipo_ofertas_renegociacao__4
# Q45RANK5             ==> tipo_ofertas_renegociacao__5
# Q46RANK1             ==> meio_pagamento_preferencial__1
# Q46RANK2             ==> meio_pagamento_preferencial__2
# Q46RANK3             ==> meio_pagamento_preferencial__3
# Q46RANK4             ==> meio_pagamento_preferencial__4
# Q46RANK5             ==> meio_pagamento_preferencial__5
# QPGTORANK1           ==> prioridadePagamentoRank__1
# QPGTORANK2           ==> prioridadePagamentoRank__2
# QPGTORANK3           ==> prioridadePagamentoRank__3
# QPGTORANK4           ==> prioridadePagamentoRank__4
# QPGTORANK5           ==> prioridadePagamentoRank__5
# QPGTORANK6           ==> prioridadePagamentoRank__6
# QPGTORANK7           ==> prioridadePagamentoRank__7
# QSFUNN1.201          ==> Conhece_Banco__Agibank
# QSFUNN1.202          ==> Conhece_Banco__AgZero
# QSFUNN1.203          ==> Conhece_Banco__BB
# QSFUNN1.204          ==> Conhece_Banco__Original
# QSFUNN1.205          ==> Conhece_Banco__Pan
# QSFUNN1.206          ==> Conhece_Banco__Bradesco
# QSFUNN1.207          ==> Conhece_Banco__BS2
# QSFUNN1.208          ==> Conhece_Banco__BTG
# QSFUNN1.209          ==> Conhece_Banco__BV
# QSFUNN1.210          ==> Conhece_Banco__C6
# QSFUNN1.211          ==> Conhece_Banco__CEF
# QSFUNN1.212          ==> Conhece_Banco__Crefisa
# QSFUNN1.213          ==> Conhece_Banco__Daycoval
# QSFUNN1.214          ==> Conhece_Banco__Digio
# QSFUNN1.215          ==> Conhece_Banco__Help
# QSFUNN1.216          ==> Conhece_Banco__Inter
# QSFUNN1.217          ==> Conhece_Banco__Itau
# QSFUNN1.218          ==> Conhece_Banco__Iti
# QSFUNN1.219          ==> Conhece_Banco__MercadoPago
# QSFUNN1.220          ==> Conhece_Banco__Neon
# QSFUNN1.221          ==> Conhece_Banco__Next
# QSFUNN1.222          ==> Conhece_Banco__Nubank
# QSFUNN1.223          ==> Conhece_Banco__PagBank
# Q28R218              ==> n_cartoes_banco__Iti
# Q28R219              ==> n_cartoes_banco__MercadoPago
# Q28R220              ==> n_cartoes_banco__Neon
# Q28R221              ==> n_cartoes_banco__Next
# Q28R222              ==> n_cartoes_banco__Nubank
# Q28R223              ==> n_cartoes_banco__PagBank
# Q28R224              ==> n_cartoes_banco__PicPay
# Q28R225              ==> n_cartoes_banco__Safra
# Q28R226              ==> n_cartoes_banco__Santander
# Q28R227              ==> n_cartoes_banco__Sicoob
# Q28R228              ==> n_cartoes_banco__Sicredi
# Q28R229              ==> n_cartoes_banco__Unicred
# +Q28R229 não encontrada.
# Q28R230              ==> n_cartoes_banco__XP
# Q28R288              ==> n_cartoes_banco__Outros
# +Q28R288 não encontrada.
# QCURRENT.201         ==> PossuiConta__Agibank
# QCURRENT.202         ==> PossuiConta__AgZero
# QCURRENT.203         ==> PossuiConta__BB
# QCURRENT.204         ==> PossuiConta__Original
# QCURRENT.205         ==> PossuiConta__Pan
# QCURRENT.206         ==> PossuiConta__Bradesco
# QCURRENT.207         ==> PossuiConta__BS2
# QCURRENT.208         ==> PossuiConta__BTG
# QCURRENT.209         ==> PossuiConta__BV
# QCURRENT.210         ==> PossuiConta__C6
# QCURRENT.211         ==> PossuiConta__CEF
# QCURRENT.212         ==> PossuiConta__Crefisa
# QCURRENT.213         ==> PossuiConta__Daycoval
# QCURRENT.214         ==> PossuiConta__Digio
# QCURRENT.215         ==> PossuiConta__Help
# QCURRENT.216         ==> PossuiConta__Inter
# QCURRENT.217         ==> PossuiConta__Itau
# QCURRENT.218         ==> PossuiConta__Iti
# QCURRENT.219         ==> PossuiConta__MercadoPago
# QCURRENT.220         ==> PossuiConta__Neon
# QCURRENT.221         ==> PossuiConta__Next
# QCURRENT.222         ==> PossuiConta__Nubank
# QCURRENT.223         ==> PossuiConta__PagBank
# QCURRENT.224         ==> PossuiConta__PicPay
# QCURRENT.225         ==> PossuiConta__Safra
# QCURRENT.226         ==> PossuiConta__Santander
# QCURRENT.227         ==> PossuiConta__Sicoob
# QCURRENT.228         ==> PossuiConta__Sicredi
# QCURRENT.229         ==> PossuiConta__Unicred
# QCURRENT.230         ==> PossuiConta__XP
# QCURRENT.288         ==> PossuiConta__Outros
# QPRODUCT_201.1       ==> ProdutoBanco__Agibank__conta poupanca
# QPRODUCT_201.2       ==> ProdutoBanco__Agibank__cheque especial
# QPRODUCT_201.3       ==> ProdutoBanco__Agibank__cartao de credito
# QPRODUCT_201.4       ==> ProdutoBanco__Agibank__credito pessoal
# QPRODUCT_201.5       ==> ProdutoBanco__Agibank__consig publico
# QPRODUCT_201.6       ==> ProdutoBanco__Agibank__consig privado
# QPRODUCT_201.7       ==> ProdutoBanco__Agibank__credito imobiliario
# QPRODUCT_201.8       ==> ProdutoBanco__Agibank__credito veiculo
# QPRODUCT_201.9       ==> ProdutoBanco__Agibank__cdc credito varejo
# QPRODUCT_201.10      ==> ProdutoBanco__Agibank__emprestimo com garantia de investimento fgts
# QPRODUCT_201.11      ==> ProdutoBanco__Agibank__emprestimo com garantia de auto ou imob
# QPRODUCT_230.5       ==> ProdutoBanco__XP__consig publico
# QPRODUCT_230.6       ==> ProdutoBanco__XP__consig privado
# QPRODUCT_230.7       ==> ProdutoBanco__XP__credito imobiliario
# QPRODUCT_230.8       ==> ProdutoBanco__XP__credito veiculo
# QPRODUCT_230.9       ==> ProdutoBanco__XP__cdc credito varejo
# QPRODUCT_230.10      ==> ProdutoBanco__XP__emprestimo com garantia de investimento fgts
# QPRODUCT_230.11      ==> ProdutoBanco__XP__emprestimo com garantia de auto ou imob
# QPRODUCT_230.12      ==> ProdutoBanco__XP__emprestimo com garantia de penhor
# QPRODUCT_230.13      ==> ProdutoBanco__XP__consorcio
# QPRODUCT_230.14      ==> ProdutoBanco__XP__investimentos
# QPRODUCT_230.15      ==> ProdutoBanco__XP__crypto
# QPRODUCT_230.16      ==> ProdutoBanco__XP__seguros
# QPRODUCT_230.97      ==> ProdutoBanco__XP__outros
# +QPRODUCT_230.97 não encontrada.
# QPRODUCT_288.1       ==> ProdutoBanco__Outros__conta poupanca
# QPRODUCT_288.2       ==> ProdutoBanco__Outros__cheque especial
# QPRODUCT_288.3       ==> ProdutoBanco__Outros__cartao de credito
# QPRODUCT_288.4       ==> ProdutoBanco__Outros__credito pessoal
# QPRODUCT_288.5       ==> ProdutoBanco__Outros__consig publico
# QPRODUCT_288.6       ==> ProdutoBanco__Outros__consig privado
# QPRODUCT_288.7       ==> ProdutoBanco__Outros__credito imobiliario
# QPRODUCT_288.8       ==> ProdutoBanco__Outros__credito veiculo
# QPRODUCT_288.9       ==> ProdutoBanco__Outros__cdc credito varejo
# QPRODUCT_288.10      ==> ProdutoBanco__Outros__emprestimo com garantia de investimento fgts
# +QPRODUCT_288.10 não encontrada.
# QPRODUCT_288.11      ==> ProdutoBanco__Outros__emprestimo com garantia de auto ou imob
# QPRODUCT_288.12      ==> ProdutoBanco__Outros__emprestimo com garantia de penhor
# QPRODUCT_288.13      ==> ProdutoBanco__Outros__consorcio
# QPRODUCT_288.14      ==> ProdutoBanco__Outros__investimentos
# QPRODUCT_288.15      ==> ProdutoBanco__Outros__crypto
# QPRODUCT_288.16      ==> ProdutoBanco__Outros__seguros
# +QPRODUCT_288.16 não encontrada.
# QPRODUCT_288.97      ==> ProdutoBanco__Outros__outros
# +QPRODUCT_288.97 não encontrada.
# Q23.1                ==> fator_mudar_banco__Credito_aprovado_com_maior_agilidade
# Q23.2                ==> fator_mudar_banco__Maior_limite_de_credito_rotativo
# Q23.3                ==> fator_mudar_banco__Maior_limite_para_financiamento
# Q23.4                ==> fator_mudar_banco__Taxas_menores_para_financiamento
# Q23.5                ==> fator_mudar_banco__Maior_prazo_ou_parcelas_mais_baratas_para_financiamento
# Q23.97               ==> fator_mudar_banco__Outros
# Q23.99               ==> fator_mudar_banco__Nada
# QATT1R101            ==> capacidade_financeira__invisto_5pct_renda
# QATT1R102            ==> capacidade_financeira__possuo_reserva_emergencia
# QATT1R103            ==> capacidade_financeira__recorro_credito
# QATT1R104            ==> capacidade_financeira__uso_cheque_especial
# QATT1R105            ==> capacidade_financeira__recorro_credito_para_compromissos
# QATT1R106            ==> capacidade_financeira__recorro_familiares
# QATT1R201            ==> endividamento__tenho_controle_despesas
# QATT1R202            ==> endividamento__perdi_sono_por_causa_dividas
# QATT1R203            ==> endividamento__gasto_mais_que_posso_pagar
# QATT1R204            ==> endividamento__tolero_aumentar_endividamento_em_caso_de_necessidade
# QATT1R205            ==> endividamento__costumo_ligar_renegociar
# QATT1R206            ==> endividamento__me_preocupo_com_atraso_apenas_apos_contato
# QATT2R101            ==> planejamento_credito__eu_me_planejo
# QATT2R102            ==> planejamento_credito__pesquiso_opcoes
# QATT2R103            ==> planejamento_credito__avalio_diferentes_instituicoes
# QATT2R104            ==> planejamento_credito__preferencialmente_banco_principal
# QATT2R105            ==> planejamento_credito__recorro_familia_amigos
# QATT2R106            ==> planejamento_credito__so_recorro_familia_amigos_quando_nao_tenho_acesso_com_bancos
# QATT2R201            ==> credito_negado__ja_tive_sem_saber_razao
# QATT2R202            ==> credito_negado__recebo_justificativa
# QATT2R203            ==> credito_negado__busco_outra_instituicao
# QATT2R204            ==> credito_negado__ja_precisei_limpar_nome
# QATT2R205            ==> credito_negado__tenho_dificuldades_mesmo_depois_de_limpar_nome
# QATT2R301            ==> situacao_credito__ult12m_consegui_guardar_dinheiro
# QATT2R302            ==> situacao_credito__ult12m_aumentei_endividamento
# QATT2R303            ==> situacao_credito__ult12m_fique_inadimplente
# Q13.1                ==> origem_dinheiro_pagamento_contas__salario
# Q13.2                ==> origem_dinheiro_pagamento_contas__vender_bens
# Q13.3                ==> origem_dinheiro_pagamento_contas__renda_extra
# Q13.4                ==> origem_dinheiro_pagamento_contas__vender_ferias
# Q13.5                ==> origem_dinheiro_pagamento_contas__reduzo_custo
# Q13.6                ==> origem_dinheiro_pagamento_contas__cobro_divida_de_terceiros
# Q13.7                ==> origem_dinheiro_pagamento_contas__uso_dinheiro_extra
# Q13.8                ==> origem_dinheiro_pagamento_contas__empresto_de_parentes
# Q13.9                ==> origem_dinheiro_pagamento_contas__outros
# +Q13.9 não encontrada.
# Q49.1                ==> tendencias__possuo_servico_streaming
# Q49.2                ==> tendencias__uso_delivery
# Q49.3                ==> tendencias__faco_compras_online
# Q49.4                ==> tendencias__possuo_redes_sociais
# Q49.5                ==> tendencias__uso_sites_apostas
# Q24R1                ==> jornada_contratacao_credito_principal__consigo_contratar_100digital
# Q24R2                ==> jornada_contratacao_credito_principal__processo_digital_intuitivo
# Q24R3                ==> jornada_contratacao_credito_principal__informacoes_sao_claras
# Q24R4                ==> jornada_contratacao_credito_principal__demandam_muitos_documentos_para_contratar_credito
# Q24R5                ==> jornada_contratacao_credito_principal__aprovacao_rapida_de_credito
# Q24R6                ==> jornada_contratacao_credito_principal__acesso_rapido_ao_dinheiro_apos_aprovacao
# Q24R7                ==> jornada_contratacao_credito_principal__o_limite_atente
# Q25RANK1             ==> fator_escolher_banco_emprestimo__1
# Q25RANK2             ==> fator_escolher_banco_emprestimo__2
# Q25RANK3             ==> fator_escolher_banco_emprestimo__3
# Q25RANK4             ==> fator_escolher_banco_emprestimo__4
# Q25RANK5             ==> fator_escolher_banco_emprestimo__5
# Q26R1                ==> cheque_especial__usei_ultimos_12m
# Q26R2                ==> cheque_especial__deveria_ser_maior
# Q26R3                ==> cheque_especial__sei_taxa_juros
# Q26R4                ==> cheque_especial__nao_uso_mesmo_tendo_limite
# Q26R5                ==> cheque_especial__nao_tenho_cheque_especial
# Q31R1                ==> cartao_credito__pretendo_obter_outro_proximos_12m
# Q31R2                ==> cartao_credito__uso_cartao_quando_nao_tenho_dinheiro_em_conta
# Q31R3                ==> cartao_credito__parcelei_nos_ult12m
# Q31R4                ==> cartao_credito__eu_sei_taxa_juros_cobrada
# Q31R5                ==> cartao_credito__eu_controlo_os_lancamentos
# Q32R1                ==> credito_parcelado__conheco_credito_consignado
# Q32R2                ==> credito_parcelado__conheco_emprestimo_pessoal
# Q32R3                ==> credito_parcelado__conheco_parcelamento_loja_varejo_cdc
# Q32R4                ==> credito_parcelado__conheco_emprestimo_com_garantia_investimentos_fgts
# Q32R5                ==> credito_parcelado__conheco_emprestimo_com_garantia_imovel_automovel
# Q32R6                ==> credito_parcelado__conheco_emprestimo_com_garantia_penhor
# Q38.1                ==> inadimplente_no_produto__cartao_loja
# Q38.2                ==> inadimplente_no_produto__cartao_credito
# Q38.3                ==> inadimplente_no_produto__carne_boleto
# Q38.4                ==> inadimplente_no_produto__cheque_devolvido
# Q38.5                ==> inadimplente_no_produto__cheque_especial
# Q38.6                ==> inadimplente_no_produto__emprestimo_pessoal
# Q38.7                ==> inadimplente_no_produto__emprestimo_com_garantia
# Q39.1                ==> gerou_inadimplencia__material_construcao
# Q39.2                ==> gerou_inadimplencia__moveis_e_eletro
# Q39.3                ==> gerou_inadimplencia__supermercado_alimentacao
# Q39.4                ==> gerou_inadimplencia__vestuario_calcados
# Q39.5                ==> gerou_inadimplencia__aluguel_condominio
# Q39.6                ==> gerou_inadimplencia__agua_luz
# Q39.7                ==> gerou_inadimplencia__tv_internet_telefone
# Q39.8                ==> gerou_inadimplencia__saude
# Q39.9                ==> gerou_inadimplencia__educacao
# Q39.10               ==> gerou_inadimplencia__viagens
# Q40.1                ==> impossibilitou_pagamento__salario_atrasado
# Q40.2                ==> impossibilitou_pagamento__desemprego_familia
# Q40.3                ==> impossibilitou_pagamento__despesa_extraordinaria
# Q40.4                ==> impossibilitou_pagamento__despesa_saude
# Q40.5                ==> impossibilitou_pagamento__despesa_aumentou
# Q40.6                ==> impossibilitou_pagamento__autonomo_reducao_renda
# Q40.7                ==> impossibilitou_pagamento__emprestei_nome_terceiros
# Q40.8                ==> impossibilitou_pagamento__esquecimento
# Q42R101              ==> atendimento_robo__costumo_desligar
# Q42R102              ==> atendimento_robo__na_ligacao_solicito_redirecionamento_humano
# Q42R103              ==> atendimento_robo__no_whats_solicito_redirecionamento_humano
# Q42R104              ==> atendimento_robo__me_sinto_confortavel_para_renegociar_divida
# Q42R105              ==> atendimento_robo__consigo_interagir_com_robo_para_renegociar
# Q42R106              ==> atendimento_robo__preciso_repetir_informacoes_entre_canais
# Q42R201              ==> personalizacao_cobranca__sou_contatado_pelo_canal_de_preferencia
# Q42R202              ==> personalizacao_cobranca__acordo_com_o_que_posso_pagar
# Q42R203              ==> personalizacao_cobranca__customizada_para_minha_situacao
# Q42R204              ==> personalizacao_cobranca__atendimento_entende_razoes_da_minha_inadimplencia
# Q51R1                ==> crediario_digital__garantia_usar_cripto
# Q51R2                ==> crediario_digital__garantia_usar_fgts
# Q51R3                ==> crediario_digital__garantia_ouro_joias
# Q51R4                ==> crediario_digital__garantia_automovel
# Q51R5                ==> crediario_digital__financiamento_auto_aceito_bloqueio_carro
# Q51R6                ==> crediario_digital__garantia_imovel
# Q51R7                ==> crediario_digital__financiamento_aceito_bloqueio_celular

# %% [markdown]
# # Salvando

# %%
df_transf.to_excel('../data/Pesquisa_Credito_PF_Cols_Renomeada.xlsx')

# %% [markdown]
# # Transpondo colunas multivaloradas

# %%
def explodeColumns(df, affix=None, columnsSelector=None, columnRenamer=None, drop=True, var_name=None, value_name='valor', addMultValor=False):
    if columnsSelector:
        selectedCols = columnsSelector(df.columns);
    elif affix:
        selectedCols = [c for c in df.columns if affix in c]
    else:
        return df

    df = df[['id']+selectedCols].copy()

    if columnRenamer:
        df = (df.rename(columns={cc:columnRenamer(cc) for cc in selectedCols}))

    df =  df.melt(id_vars='id', var_name=var_name, value_name=value_name)

    if addMultValor:
        df = df.assign(categoria=affix)

    return df, selectedCols

# %%
def processaNPS(df_transf2):
    selectedCols_nps = []
    perguntas = [
        {'affix':'cartao_credito','replacer':'cartao_credito__', 'var_name':'pergunta', 'value_name':'nps'},
        {'affix':'endividamento','replacer':'endividamento__', 'var_name':'pergunta', 'value_name':'nps'},
        {'affix':'personalizacao_cobranca','replacer':'personalizacao_cobranca__', 'var_name':'pergunta', 'value_name':'nps'},
        {'affix':'atendimento_robo','replacer':'atendimento_robo__', 'var_name':'pergunta', 'value_name':'nps'},
        
        {'affix':'planejamento_credito','replacer':'planejamento_credito__', 'var_name':'pergunta', 'value_name':'nps'},
        {'affix':'cheque_especial','replacer':'cheque_especial__', 'var_name':'pergunta', 'value_name':'nps'},
        {'affix':'jornada_contratacao_credito_principal','replacer':'jornada_contratacao_credito_principal__', 'var_name':'pergunta', 'value_name':'nps'},
        {'affix':'credito_negado','replacer':'credito_negado__', 'var_name':'pergunta', 'value_name':'nps'},
        {'affix':'capacidade_financeira','replacer':'capacidade_financeira__', 'var_name':'pergunta', 'value_name':'nps'},
        
        {'affix':'situacao_credito','replacer':'situacao_credito__', 'var_name':'pergunta', 'value_name':'nps'},
        {'affix':'credito_parcelado','replacer':'credito_parcelado__', 'var_name':'pergunta', 'value_name':'nps'},
        {'affix':'crediario_digital','replacer':'crediario_digital__', 'var_name':'pergunta', 'value_name':'nps'},
    ]

    
    df_nps_list = [];
    
    for pergunta in perguntas:
        df_nps, selectedCols = explodeColumns(
            df_transf2,
            affix=pergunta['affix'],
            var_name=pergunta['var_name'],
            value_name=pergunta['value_name'],
            columnsSelector=lambda cols: [x for x in cols if x.startswith(pergunta['affix']+'__') and not re.match(r'.*\d+$',x)],
            columnRenamer=lambda x:x.replace(pergunta['replacer'],''),
            addMultValor=True
        )
        df_nps_list.append( df_nps.dropna())
        selectedCols_nps+=selectedCols
    
    return pd.concat(df_nps_list), selectedCols_nps

# %%
def processaRanks(df_transf2):
    selectedCols_geral = []
    perguntas = [
        {'affix':'prioridadePagamentoRank','replacer':'prioridadePagamentoRank__', 'var_name':'rank', 'value_name':'prioridade'},
        {'affix':'canal_contratacao_prioridade','replacer':'canal_contratacao_prioridade__', 'var_name':'rank', 'value_name':'prioridade'},
        
        
        {'affix':'fator_escolher_banco_emprestimo','replacer':'fator_escolher_banco_emprestimo__', 'var_name':'rank', 'value_name':'prioridade'},
        {'affix':'cartao_credito_novo__importancia','replacer':'cartao_credito_novo__importancia__', 'var_name':'rank', 'value_name':'prioridade'},
        {'affix':'credito_parcelado_novo__importancia','replacer':'credito_parcelado_novo__importancia__', 'var_name':'rank', 'value_name':'prioridade'},
        {'affix':'inadimplencia__melhor_forma_de_saber','replacer':'inadimplencia__melhor_forma_de_saber__', 'var_name':'rank', 'value_name':'prioridade'},
        {'affix':'melhorias_processo_cobranca','replacer':'melhorias_processo_cobranca__', 'var_name':'rank', 'value_name':'prioridade'},
        {'affix':'tipo_ofertas_renegociacao','replacer':'tipo_ofertas_renegociacao__', 'var_name':'rank', 'value_name':'prioridade'},
        {'affix':'meio_pagamento_preferencial','replacer':'meio_pagamento_preferencial__', 'var_name':'rank', 'value_name':'prioridade'},
        
    ]

    
    df_list = [];
    
    for pergunta in perguntas:
        df_ranks, selectedCols = explodeColumns(
            df_transf2,
            affix=pergunta['affix'],
            var_name=pergunta['var_name'],
            value_name=pergunta['value_name'],
            columnsSelector=lambda cols: [x for x in cols if x.startswith(pergunta['affix']+'__')],
            columnRenamer=lambda x:x.replace(pergunta['replacer'],''),
            addMultValor=True
        )
        df_list.append( df_ranks.dropna())
        selectedCols_geral+=selectedCols
    
    return pd.concat(df_list), selectedCols_geral

# %%
def processaBoolean(df_transf2):
    selectedCols_geral = []
    perguntas = [
        {'affix':'origem_dinheiro_pagamento_contas','replacer':'origem_dinheiro_pagamento_contas__', 'var_name':'rank', 'value_name':'valor'},
        {'affix':'gerou_inadimplencia','replacer':'gerou_inadimplencia__', 'var_name':'rank', 'value_name':'valor'},
        {'affix':'impossibilitou_pagamento','replacer':'impossibilitou_pagamento__', 'var_name':'rank', 'value_name':'valor'},
        {'affix':'inadimplente_no_produto','replacer':'inadimplente_no_produto__', 'var_name':'rank', 'value_name':'valor'},
        {'affix':'fator_mudar_banco','replacer':'fator_mudar_banco__', 'var_name':'rank', 'value_name':'valor'},
        {'affix':'tendencias','replacer':'tendencias__', 'var_name':'rank', 'value_name':'valor'},
        
    ]

    
    df_list = [];
    
    for pergunta in perguntas:
        df_ranks, selectedCols = explodeColumns(
            df_transf2,
            affix=pergunta['affix'],
            var_name=pergunta['var_name'],
            value_name=pergunta['value_name'],
            columnsSelector=lambda cols: [x for x in cols if x.startswith(pergunta['affix']+'__')],
            columnRenamer=lambda x:x.replace(pergunta['replacer'],''),
            addMultValor=True
        )
        df_list.append( df_ranks.dropna())
        selectedCols_geral+=selectedCols
    
    return pd.concat(df_list), selectedCols_geral

# %%
df_transf2 = df_transf.copy()

columns2drop =[]

###############
df_depara = (
    pd.DataFrame(depara_colunas, columns=['Nome na pesquisa', 'Nome Renomeado'])
)

################ Conhece Banco
print('Conhece Banco')
df_conhece_banco, selectedCols = explodeColumns(
    df_transf2,
    affix='Conhece_Banco',
    var_name='banco',
    columnRenamer=lambda x:x.replace('Conhece_Banco__','')
)
columns2drop += selectedCols




################ Considera_Contracao
print('Considera_Contracao')
df_considera_contracao, selectedCols = explodeColumns(
    df_transf2,
    affix='Considera_Contracao',
    var_name='banco',
    columnRenamer=lambda x:x.replace('Considera_Contracao__','')
)
columns2drop += selectedCols

################ Possui conta
print('Possui conta')
df_PossuiConta, selectedCols = explodeColumns(
    df_transf2,
    affix='PossuiConta',
    var_name='banco',
    columnRenamer=lambda x:x.replace('PossuiConta__','')
)
columns2drop += selectedCols


################ produto banco
print('produto banco')
df_possui_produto_banco, selectedCols = explodeColumns(
    df_transf2,
    affix='ProdutoBanco',
    var_name='ProdutoBanco',
    columnRenamer=lambda x:x.replace('ProdutoBanco__','')
)
df_possui_produto_banco = (
    df_possui_produto_banco
    .query("valor == 'Sim'")
    .assign(ProdutoBanco=lambda x:x['ProdutoBanco'].str.split('__'))
    .assign(banco=lambda x:x['ProdutoBanco'].apply(lambda x:x[0]))
    .assign(produto=lambda x:x['ProdutoBanco'].apply(lambda x:x[1]))
    .drop(columns=['ProdutoBanco','valor'])
)
columns2drop += selectedCols


#### numero de cartoes por banco
print('numero de cartoes por banco')
df_n_cartoes_banco, selectedCols = explodeColumns(
    df_transf2,
    affix='n_cartoes_banco',
    var_name='ProdutoBanco',
    value_name='n_cartoes',
    columnRenamer=lambda x:x.replace('n_cartoes_banco__','')
)
df_n_cartoes_banco = df_n_cartoes_banco.dropna().query('n_cartoes >0')
columns2drop += selectedCols


#### Consolida perguntas do tipo NPS
print('columns NPS')
df_nps, selectedCols = processaNPS(df_transf2)
df_nps = df_nps.dropna()
columns2drop += selectedCols

#### Consolida perguntas do tipo NPS
print('Ranking Coluns')
df_ranks, selectedCols = processaRanks(df_transf2)
columns2drop += selectedCols

#### Consolida perguntas do tipo Booleans
# print('Ranking Booleans - Não serão deletadas')
# df_bools, selectedCols = processaBoolean(df_transf2)
# columns2drop += selectedCols

df_transf2.drop(columns=[c for c in columns2drop if c in df_transf2.columns], inplace=True)
print('Processo concluído')
# Out:
# Conhece Banco
# Considera_Contracao
# Possui conta
# produto banco
# numero de cartoes por banco
# columns NPS
# Ranking Coluns
# Processo concluído

# %%
writer = pd.ExcelWriter("../data/Pesquisa Credito PF - compacta.xlsx", engine='xlsxwriter')
df_transf2.to_excel(writer,sheet_name='pesquisa')
df_depara.to_excel(writer,sheet_name='De-para colunas', index=False)
df_conhece_banco.to_excel(writer,sheet_name='conhece_banco', index=False)

# Salvando só quem tem conta
df_PossuiConta.query('valor == "Sim"').drop(columns='valor').to_excel(writer,sheet_name='possui_banco', index=False)
df_considera_contracao.dropna().to_excel(writer,  sheet_name='considera_contratar_no_banco', index=False)


# Salvando só quem tem produto no banco
df_possui_produto_banco.to_excel(writer,sheet_name='produto_por_banco', index=False)

####
df_n_cartoes_banco.to_excel(writer,sheet_name='cartoes_por_banco', index=False)

####
df_nps.to_excel(writer,sheet_name='questoes_nps', index=False)

####
df_ranks.to_excel(writer,sheet_name='questoes_ranking', index=False)

writer.close()
print('Processo concluído')
# Out:
# Processo concluído

# %%
#df_considera_contracao.dropna()

# %%
df_bools, selectedCols = processaBoolean(df_transf2)
df_bools.pivot_table(index=['categoria','rank'], columns=['valor'], values='id', aggfunc='nunique', dropna=True, margins=True)
# Out:
# valor                                                                                Aposentadoria  \
# categoria                        rank
# fator_mudar_banco                Credito_aprovado_com_maior_agilidade                          NaN
#                                  Maior_limite_de_credito_rotativo                              NaN
#                                  Maior_limite_para_financiamento                               NaN
#                                  Maior_prazo_ou_parcelas_mais_baratas_para_finan...            NaN
#                                  Nada                                                          NaN
#                                  Outros                                                        NaN
#                                  Taxas_menores_para_financiamento                              NaN
# gerou_inadimplencia              agua_luz                                                      NaN
#                                  aluguel_condominio                                            NaN
#                                  educacao                                                      NaN
#                                  material_construcao                                           NaN
#                                  moveis_e_eletro                                               NaN
#                                  saude                                                         NaN
#                                  supermercado_alimentacao                                      NaN
#                                  tv_internet_telefone                                          NaN
#                                  vestuario_calcados                                            NaN
#                                  viagens                                                       NaN
# impossibilitou_pagamento         autonomo_reducao_renda                                        NaN
#                                  desemprego_familia                                            NaN
#                                  despesa_aumentou                                              NaN
#                                  despesa_extraordinaria                                        NaN
#                                  despesa_saude                                                 NaN
#                                  emprestei_nome_terceiros                                      NaN
#                                  esquecimento                                                  NaN
#                                  salario_atrasado                                              NaN
# inadimplente_no_produto          carne_boleto                                                  NaN
#                                  cartao_credito                                                NaN
#                                  cartao_loja                                                   NaN
#                                  cheque_devolvido                                              NaN
#                                  cheque_especial                                               NaN
#                                  emprestimo_com_garantia                                       NaN
#                                  emprestimo_pessoal                                            NaN
# origem_dinheiro_pagamento_contas cobro_divida_de_terceiros                                     NaN
#                                  empresto_de_parentes                                          NaN
#                                  outros                                                      4.000
#                                  reduzo_custo                                                  NaN
#                                  renda_extra                                                   NaN
#                                  salario                                                       NaN
#                                  uso_dinheiro_extra                                            NaN
#                                  vender_bens                                                   NaN
#                                  vender_ferias                                                 NaN
# tendencias                       faco_compras_online                                           NaN
#                                  possuo_redes_sociais                                          NaN
#                                  possuo_servico_streaming                                      NaN
#                                  uso_delivery                                                  NaN
#                                  uso_sites_apostas                                             NaN
# All                                                                                          4.000
#
# valor                                                                                Aposentda  \
# categoria                        rank
# fator_mudar_banco                Credito_aprovado_com_maior_agilidade                      NaN
#                                  Maior_limite_de_credito_rotativo                          NaN
#                                  Maior_limite_para_financiamento                           NaN
#                                  Maior_prazo_ou_parcelas_mais_baratas_para_finan...        NaN
#                                  Nada                                                      NaN
#                                  Outros                                                    NaN
#                                  Taxas_menores_para_financiamento                          NaN
# gerou_inadimplencia              agua_luz                                                  NaN
#                                  aluguel_condominio                                        NaN
#                                  educacao                                                  NaN
#                                  material_construcao                                       NaN
#                                  moveis_e_eletro                                           NaN
#                                  saude                                                     NaN
#                                  supermercado_alimentacao                                  NaN
#                                  tv_internet_telefone                                      NaN
#                                  vestuario_calcados                                        NaN
#                                  viagens                                                   NaN
# impossibilitou_pagamento         autonomo_reducao_renda                                    NaN
#                                  desemprego_familia                                        NaN
#                                  despesa_aumentou                                          NaN
#                                  despesa_extraordinaria                                    NaN
#                                  despesa_saude                                             NaN
#                                  emprestei_nome_terceiros                                  NaN
#                                  esquecimento                                              NaN
#                                  salario_atrasado                                          NaN
# inadimplente_no_produto          carne_boleto                                              NaN
#                                  cartao_credito                                            NaN
#                                  cartao_loja                                               NaN
#                                  cheque_devolvido                                          NaN
#                                  cheque_especial                                           NaN
#                                  emprestimo_com_garantia                                   NaN
#                                  emprestimo_pessoal                                        NaN
# origem_dinheiro_pagamento_contas cobro_divida_de_terceiros                                 NaN
#                                  empresto_de_parentes                                      NaN
#                                  outros                                                  1.000
#                                  reduzo_custo                                              NaN
#                                  renda_extra                                               NaN
#                                  salario                                                   NaN
#                                  uso_dinheiro_extra                                        NaN
#                                  vender_bens                                               NaN
#                                  vender_ferias                                             NaN
# tendencias                       faco_compras_online                                       NaN
#                                  possuo_redes_sociais                                      NaN
#                                  possuo_servico_streaming                                  NaN
#                                  uso_delivery                                              NaN
#                                  uso_sites_apostas                                         NaN
# All                                                                                      1.000
#
# valor                                                                                Auxílio emergencial  \
# categoria                        rank
# fator_mudar_banco                Credito_aprovado_com_maior_agilidade                                NaN
#                                  Maior_limite_de_credito_rotativo                                    NaN
#                                  Maior_limite_para_financiamento                                     NaN
#                                  Maior_prazo_ou_parcelas_mais_baratas_para_finan...                  NaN
#                                  Nada                                                                NaN
#                                  Outros                                                              NaN
#                                  Taxas_menores_para_financiamento                                    NaN
# gerou_inadimplencia              agua_luz                                                            NaN
#                                  aluguel_condominio                                                  NaN
#                                  educacao                                                            NaN
#                                  material_construcao                                                 NaN
#                                  moveis_e_eletro                                                     NaN
#                                  saude                                                               NaN
#                                  supermercado_alimentacao                                            NaN
#                                  tv_internet_telefone                                                NaN
#                                  vestuario_calcados                                                  NaN
#                                  viagens                                                             NaN
# impossibilitou_pagamento         autonomo_reducao_renda                                              NaN
#                                  desemprego_familia                                                  NaN
#                                  despesa_aumentou                                                    NaN
#                                  despesa_extraordinaria                                              NaN
#                                  despesa_saude                                                       NaN
#                                  emprestei_nome_terceiros                                            NaN
#                                  esquecimento                                                        NaN
#                                  salario_atrasado                                                    NaN
# inadimplente_no_produto          carne_boleto                                                        NaN
#                                  cartao_credito                                                      NaN
#                                  cartao_loja                                                         NaN
#                                  cheque_devolvido                                                    NaN
#                                  cheque_especial                                                     NaN
#                                  emprestimo_com_garantia                                             NaN
#                                  emprestimo_pessoal                                                  NaN
# origem_dinheiro_pagamento_contas cobro_divida_de_terceiros                                           NaN
#                                  empresto_de_parentes                                                NaN
#                                  outros                                                            1.000
#                                  reduzo_custo                                                        NaN
#                                  renda_extra                                                         NaN
#                                  salario                                                             NaN
#                                  uso_dinheiro_extra                                                  NaN
#                                  vender_bens                                                         NaN
#                                  vender_ferias                                                       NaN
# tendencias                       faco_compras_online                                                 NaN
#                                  possuo_redes_sociais                                                NaN
#                                  possuo_servico_streaming                                            NaN
#                                  uso_delivery                                                        NaN
#                                  uso_sites_apostas                                                   NaN
# All                                                                                                1.000
#
# valor                                                                                Bolsa Família  \
# categoria                        rank
# fator_mudar_banco                Credito_aprovado_com_maior_agilidade                          NaN
#                                  Maior_limite_de_credito_rotativo                              NaN
#                                  Maior_limite_para_financiamento                               NaN
#                                  Maior_prazo_ou_parcelas_mais_baratas_para_finan...            NaN
#                                  Nada                                                          NaN
#                                  Outros                                                        NaN
#                                  Taxas_menores_para_financiamento                              NaN
# gerou_inadimplencia              agua_luz                                                      NaN
#                                  aluguel_condominio                                            NaN
#                                  educacao                                                      NaN
#                                  material_construcao                                           NaN
#                                  moveis_e_eletro                                               NaN
#                                  saude                                                         NaN
#                                  supermercado_alimentacao                                      NaN
#                                  tv_internet_telefone                                          NaN
#                                  vestuario_calcados                                            NaN
#                                  viagens                                                       NaN
# impossibilitou_pagamento         autonomo_reducao_renda                                        NaN
#                                  desemprego_familia                                            NaN
#                                  despesa_aumentou                                              NaN
#                                  despesa_extraordinaria                                        NaN
#                                  despesa_saude                                                 NaN
#                                  emprestei_nome_terceiros                                      NaN
#                                  esquecimento                                                  NaN
#                                  salario_atrasado                                              NaN
# inadimplente_no_produto          carne_boleto                                                  NaN
#                                  cartao_credito                                                NaN
#                                  cartao_loja                                                   NaN
#                                  cheque_devolvido                                              NaN
#                                  cheque_especial                                               NaN
#                                  emprestimo_com_garantia                                       NaN
#                                  emprestimo_pessoal                                            NaN
# origem_dinheiro_pagamento_contas cobro_divida_de_terceiros                                     NaN
#                                  empresto_de_parentes                                          NaN
#                                  outros                                                      1.000
#                                  reduzo_custo                                                  NaN
#                                  renda_extra                                                   NaN
#                                  salario                                                       NaN
#                                  uso_dinheiro_extra                                            NaN
#                                  vender_bens                                                   NaN
#                                  vender_ferias                                                 NaN
# tendencias                       faco_compras_online                                           NaN
#                                  possuo_redes_sociais                                          NaN
#                                  possuo_servico_streaming                                      NaN
#                                  uso_delivery                                                  NaN
#                                  uso_sites_apostas                                             NaN
# All                                                                                          1.000
#
# valor                                                                                Bolsa família  \
# categoria                        rank
# fator_mudar_banco                Credito_aprovado_com_maior_agilidade                          NaN
#                                  Maior_limite_de_credito_rotativo                              NaN
#                                  Maior_limite_para_financiamento                               NaN
#                                  Maior_prazo_ou_parcelas_mais_baratas_para_finan...            NaN
#                                  Nada                                                          NaN
#                                  Outros                                                        NaN
#                                  Taxas_menores_para_financiamento                              NaN
# gerou_inadimplencia              agua_luz                                                      NaN
#                                  aluguel_condominio                                            NaN
#                                  educacao                                                      NaN
#                                  material_construcao                                           NaN
#                                  moveis_e_eletro                                               NaN
#                                  saude                                                         NaN
#                                  supermercado_alimentacao                                      NaN
#                                  tv_internet_telefone                                          NaN
#                                  vestuario_calcados                                            NaN
#                                  viagens                                                       NaN
# impossibilitou_pagamento         autonomo_reducao_renda                                        NaN
#                                  desemprego_familia                                            NaN
#                                  despesa_aumentou                                              NaN
#                                  despesa_extraordinaria                                        NaN
#                                  despesa_saude                                                 NaN
#                                  emprestei_nome_terceiros                                      NaN
#                                  esquecimento                                                  NaN
#                                  salario_atrasado                                              NaN
# inadimplente_no_produto          carne_boleto                                                  NaN
#                                  cartao_credito                                                NaN
#                                  cartao_loja                                                   NaN
#                                  cheque_devolvido                                              NaN
#                                  cheque_especial                                               NaN
#                                  emprestimo_com_garantia                                       NaN
#                                  emprestimo_pessoal                                            NaN
# origem_dinheiro_pagamento_contas cobro_divida_de_terceiros                                     NaN
#                                  empresto_de_parentes                                          NaN
#                                  outros                                                      1.000
#                                  reduzo_custo                                                  NaN
#                                  renda_extra                                                   NaN
#                                  salario                                                       NaN
#                                  uso_dinheiro_extra                                            NaN
#                                  vender_bens                                                   NaN
#                                  vender_ferias                                                 NaN
# tendencias                       faco_compras_online                                           NaN
#                                  possuo_redes_sociais                                          NaN
#                                  possuo_servico_streaming                                      NaN
#                                  uso_delivery                                                  NaN
#                                  uso_sites_apostas                                             NaN
# All                                                                                          1.000
#
# valor                                                                                Dependo do meu esposo  \
# categoria                        rank
# fator_mudar_banco                Credito_aprovado_com_maior_agilidade                                  NaN
#                                  Maior_limite_de_credito_rotativo                                      NaN
#                                  Maior_limite_para_financiamento                                       NaN
#                                  Maior_prazo_ou_parcelas_mais_baratas_para_finan...                    NaN
#                                  Nada                                                                  NaN
#                                  Outros                                                                NaN
#                                  Taxas_menores_para_financiamento                                      NaN
# gerou_inadimplencia              agua_luz                                                              NaN
#                                  aluguel_condominio                                                    NaN
#                                  educacao                                                              NaN
#                                  material_construcao                                                   NaN
#                                  moveis_e_eletro                                                       NaN
#                                  saude                                                                 NaN
#                                  supermercado_alimentacao                                              NaN
#                                  tv_internet_telefone                                                  NaN
#                                  vestuario_calcados                                                    NaN
#                                  viagens                                                               NaN
# impossibilitou_pagamento         autonomo_reducao_renda                                                NaN
#                                  desemprego_familia                                                    NaN
#                                  despesa_aumentou                                                      NaN
#                                  despesa_extraordinaria                                                NaN
#                                  despesa_saude                                                         NaN
#                                  emprestei_nome_terceiros                                              NaN
#                                  esquecimento                                                          NaN
#                                  salario_atrasado                                                      NaN
# inadimplente_no_produto          carne_boleto                                                          NaN
#                                  cartao_credito                                                        NaN
#                                  cartao_loja                                                           NaN
#                                  cheque_devolvido                                                      NaN
#                                  cheque_especial                                                       NaN
#                                  emprestimo_com_garantia                                               NaN
#                                  emprestimo_pessoal                                                    NaN
# origem_dinheiro_pagamento_contas cobro_divida_de_terceiros                                             NaN
#                                  empresto_de_parentes                                                  NaN
#                                  outros                                                              1.000
#                                  reduzo_custo                                                          NaN
#                                  renda_extra                                                           NaN
#                                  salario                                                               NaN
#                                  uso_dinheiro_extra                                                    NaN
#                                  vender_bens                                                           NaN
#                                  vender_ferias                                                         NaN
# tendencias                       faco_compras_online                                                   NaN
#                                  possuo_redes_sociais                                                  NaN
#                                  possuo_servico_streaming                                              NaN
#                                  uso_delivery                                                          NaN
#                                  uso_sites_apostas                                                     NaN
# All                                                                                                  1.000
#
# valor                                                                                Eu não trabalho  \
# categoria                        rank
# fator_mudar_banco                Credito_aprovado_com_maior_agilidade                            NaN
#                                  Maior_limite_de_credito_rotativo                                NaN
#                                  Maior_limite_para_financiamento                                 NaN
#                                  Maior_prazo_ou_parcelas_mais_baratas_para_finan...              NaN
#                                  Nada                                                            NaN
#                                  Outros                                                          NaN
#                                  Taxas_menores_para_financiamento                                NaN
# gerou_inadimplencia              agua_luz                                                        NaN
#                                  aluguel_condominio                                              NaN
#                                  educacao                                                        NaN
#                                  material_construcao                                             NaN
#                                  moveis_e_eletro                                                 NaN
#                                  saude                                                           NaN
#                                  supermercado_alimentacao                                        NaN
#                                  tv_internet_telefone                                            NaN
#                                  vestuario_calcados                                              NaN
#                                  viagens                                                         NaN
# impossibilitou_pagamento         autonomo_reducao_renda                                          NaN
#                                  desemprego_familia                                              NaN
#                                  despesa_aumentou                                                NaN
#                                  despesa_extraordinaria                                          NaN
#                                  despesa_saude                                                   NaN
#                                  emprestei_nome_terceiros                                        NaN
#                                  esquecimento                                                    NaN
#                                  salario_atrasado                                                NaN
# inadimplente_no_produto          carne_boleto                                                    NaN
#                                  cartao_credito                                                  NaN
#                                  cartao_loja                                                     NaN
#                                  cheque_devolvido                                                NaN
#                                  cheque_especial                                                 NaN
#                                  emprestimo_com_garantia                                         NaN
#                                  emprestimo_pessoal                                              NaN
# origem_dinheiro_pagamento_contas cobro_divida_de_terceiros                                       NaN
#                                  empresto_de_parentes                                            NaN
#                                  outros                                                        1.000
#                                  reduzo_custo                                                    NaN
#                                  renda_extra                                                     NaN
#                                  salario                                                         NaN
#                                  uso_dinheiro_extra                                              NaN
#                                  vender_bens                                                     NaN
#                                  vender_ferias                                                   NaN
# tendencias                       faco_compras_online                                             NaN
#                                  possuo_redes_sociais                                            NaN
#                                  possuo_servico_streaming                                        NaN
#                                  uso_delivery                                                    NaN
#                                  uso_sites_apostas                                               NaN
# All                                                                                            1.000
#
# valor                                                                                Faço cabelos  \
# categoria                        rank
# fator_mudar_banco                Credito_aprovado_com_maior_agilidade                         NaN
#                                  Maior_limite_de_credito_rotativo                             NaN
#                                  Maior_limite_para_financiamento                              NaN
#                                  Maior_prazo_ou_parcelas_mais_baratas_para_finan...           NaN
#                                  Nada                                                         NaN
#                                  Outros                                                       NaN
#                                  Taxas_menores_para_financiamento                             NaN
# gerou_inadimplencia              agua_luz                                                     NaN
#                                  aluguel_condominio                                           NaN
#                                  educacao                                                     NaN
#                                  material_construcao                                          NaN
#                                  moveis_e_eletro                                              NaN
#                                  saude                                                        NaN
#                                  supermercado_alimentacao                                     NaN
#                                  tv_internet_telefone                                         NaN
#                                  vestuario_calcados                                           NaN
#                                  viagens                                                      NaN
# impossibilitou_pagamento         autonomo_reducao_renda                                       NaN
#                                  desemprego_familia                                           NaN
#                                  despesa_aumentou                                             NaN
#                                  despesa_extraordinaria                                       NaN
#                                  despesa_saude                                                NaN
#                                  emprestei_nome_terceiros                                     NaN
#                                  esquecimento                                                 NaN
#                                  salario_atrasado                                             NaN
# inadimplente_no_produto          carne_boleto                                                 NaN
#                                  cartao_credito                                               NaN
#                                  cartao_loja                                                  NaN
#                                  cheque_devolvido                                             NaN
#                                  cheque_especial                                              NaN
#                                  emprestimo_com_garantia                                      NaN
#                                  emprestimo_pessoal                                           NaN
# origem_dinheiro_pagamento_contas cobro_divida_de_terceiros                                    NaN
#                                  empresto_de_parentes                                         NaN
#                                  outros                                                     1.000
#                                  reduzo_custo                                                 NaN
#                                  renda_extra                                                  NaN
#                                  salario                                                      NaN
#                                  uso_dinheiro_extra                                           NaN
#                                  vender_bens                                                  NaN
#                                  vender_ferias                                                NaN
# tendencias                       faco_compras_online                                          NaN
#                                  possuo_redes_sociais                                         NaN
#                                  possuo_servico_streaming                                     NaN
#                                  uso_delivery                                                 NaN
#                                  uso_sites_apostas                                            NaN
# All                                                                                         1.000
#
# valor                                                                                Fontes de renda  \
# categoria                        rank
# fator_mudar_banco                Credito_aprovado_com_maior_agilidade                            NaN
#                                  Maior_limite_de_credito_rotativo                                NaN
#                                  Maior_limite_para_financiamento                                 NaN
#                                  Maior_prazo_ou_parcelas_mais_baratas_para_finan...              NaN
#                                  Nada                                                            NaN
#                                  Outros                                                          NaN
#                                  Taxas_menores_para_financiamento                                NaN
# gerou_inadimplencia              agua_luz                                                        NaN
#                                  aluguel_condominio                                              NaN
#                                  educacao                                                        NaN
#                                  material_construcao                                             NaN
#                                  moveis_e_eletro                                                 NaN
#                                  saude                                                           NaN
#                                  supermercado_alimentacao                                        NaN
#                                  tv_internet_telefone                                            NaN
#                                  vestuario_calcados                                              NaN
#                                  viagens                                                         NaN
# impossibilitou_pagamento         autonomo_reducao_renda                                          NaN
#                                  desemprego_familia                                              NaN
#                                  despesa_aumentou                                                NaN
#                                  despesa_extraordinaria                                          NaN
#                                  despesa_saude                                                   NaN
#                                  emprestei_nome_terceiros                                        NaN
#                                  esquecimento                                                    NaN
#                                  salario_atrasado                                                NaN
# inadimplente_no_produto          carne_boleto                                                    NaN
#                                  cartao_credito                                                  NaN
#                                  cartao_loja                                                     NaN
#                                  cheque_devolvido                                                NaN
#                                  cheque_especial                                                 NaN
#                                  emprestimo_com_garantia                                         NaN
#                                  emprestimo_pessoal                                              NaN
# origem_dinheiro_pagamento_contas cobro_divida_de_terceiros                                       NaN
#                                  empresto_de_parentes                                            NaN
#                                  outros                                                        1.000
#                                  reduzo_custo                                                    NaN
#                                  renda_extra                                                     NaN
#                                  salario                                                         NaN
#                                  uso_dinheiro_extra                                              NaN
#                                  vender_bens                                                     NaN
#                                  vender_ferias                                                   NaN
# tendencias                       faco_compras_online                                             NaN
#                                  possuo_redes_sociais                                            NaN
#                                  possuo_servico_streaming                                        NaN
#                                  uso_delivery                                                    NaN
#                                  uso_sites_apostas                                               NaN
# All                                                                                            1.000
#
# valor                                                                                Investimentos  \
# categoria                        rank
# fator_mudar_banco                Credito_aprovado_com_maior_agilidade                          NaN
#                                  Maior_limite_de_credito_rotativo                              NaN
#                                  Maior_limite_para_financiamento                               NaN
#                                  Maior_prazo_ou_parcelas_mais_baratas_para_finan...            NaN
#                                  Nada                                                          NaN
#                                  Outros                                                        NaN
#                                  Taxas_menores_para_financiamento                              NaN
# gerou_inadimplencia              agua_luz                                                      NaN
#                                  aluguel_condominio                                            NaN
#                                  educacao                                                      NaN
#                                  material_construcao                                           NaN
#                                  moveis_e_eletro                                               NaN
#                                  saude                                                         NaN
#                                  supermercado_alimentacao                                      NaN
#                                  tv_internet_telefone                                          NaN
#                                  vestuario_calcados                                            NaN
#                                  viagens                                                       NaN
# impossibilitou_pagamento         autonomo_reducao_renda                                        NaN
#                                  desemprego_familia                                            NaN
#                                  despesa_aumentou                                              NaN
#                                  despesa_extraordinaria                                        NaN
# ...
#                                  emprestimo_pessoal                                                    NaN
# origem_dinheiro_pagamento_contas cobro_divida_de_terceiros                                             NaN
#                                  empresto_de_parentes                                                  NaN
#                                  outros                                                              1.000
#                                  reduzo_custo                                                          NaN
#                                  renda_extra                                                           NaN
#                                  salario                                                               NaN
#                                  uso_dinheiro_extra                                                    NaN
#                                  vender_bens                                                           NaN
#                                  vender_ferias                                                         NaN
# tendencias                       faco_compras_online                                                   NaN
#                                  possuo_redes_sociais                                                  NaN
#                                  possuo_servico_streaming                                              NaN
#                                  uso_delivery                                                          NaN
#                                  uso_sites_apostas                                                     NaN
# All                                                                                                  1.000
#
# valor                                                                                pais  \
# categoria                        rank
# fator_mudar_banco                Credito_aprovado_com_maior_agilidade                 NaN
#                                  Maior_limite_de_credito_rotativo                     NaN
#                                  Maior_limite_para_financiamento                      NaN
#                                  Maior_prazo_ou_parcelas_mais_baratas_para_finan...   NaN
#                                  Nada                                                 NaN
#                                  Outros                                               NaN
#                                  Taxas_menores_para_financiamento                     NaN
# gerou_inadimplencia              agua_luz                                             NaN
#                                  aluguel_condominio                                   NaN
#                                  educacao                                             NaN
#                                  material_construcao                                  NaN
#                                  moveis_e_eletro                                      NaN
#                                  saude                                                NaN
#                                  supermercado_alimentacao                             NaN
#                                  tv_internet_telefone                                 NaN
#                                  vestuario_calcados                                   NaN
#                                  viagens                                              NaN
# impossibilitou_pagamento         autonomo_reducao_renda                               NaN
#                                  desemprego_familia                                   NaN
#                                  despesa_aumentou                                     NaN
#                                  despesa_extraordinaria                               NaN
#                                  despesa_saude                                        NaN
#                                  emprestei_nome_terceiros                             NaN
#                                  esquecimento                                         NaN
#                                  salario_atrasado                                     NaN
# inadimplente_no_produto          carne_boleto                                         NaN
#                                  cartao_credito                                       NaN
#                                  cartao_loja                                          NaN
#                                  cheque_devolvido                                     NaN
#                                  cheque_especial                                      NaN
#                                  emprestimo_com_garantia                              NaN
#                                  emprestimo_pessoal                                   NaN
# origem_dinheiro_pagamento_contas cobro_divida_de_terceiros                            NaN
#                                  empresto_de_parentes                                 NaN
#                                  outros                                             1.000
#                                  reduzo_custo                                         NaN
#                                  renda_extra                                          NaN
#                                  salario                                              NaN
#                                  uso_dinheiro_extra                                   NaN
#                                  vender_bens                                          NaN
#                                  vender_ferias                                        NaN
# tendencias                       faco_compras_online                                  NaN
#                                  possuo_redes_sociais                                 NaN
#                                  possuo_servico_streaming                             NaN
#                                  uso_delivery                                         NaN
#                                  uso_sites_apostas                                    NaN
# All                                                                                 1.000
#
# valor                                                                                serviços extras  \
# categoria                        rank
# fator_mudar_banco                Credito_aprovado_com_maior_agilidade                            NaN
#                                  Maior_limite_de_credito_rotativo                                NaN
#                                  Maior_limite_para_financiamento                                 NaN
#                                  Maior_prazo_ou_parcelas_mais_baratas_para_finan...              NaN
#                                  Nada                                                            NaN
#                                  Outros                                                          NaN
#                                  Taxas_menores_para_financiamento                                NaN
# gerou_inadimplencia              agua_luz                                                        NaN
#                                  aluguel_condominio                                              NaN
#                                  educacao                                                        NaN
#                                  material_construcao                                             NaN
#                                  moveis_e_eletro                                                 NaN
#                                  saude                                                           NaN
#                                  supermercado_alimentacao                                        NaN
#                                  tv_internet_telefone                                            NaN
#                                  vestuario_calcados                                              NaN
#                                  viagens                                                         NaN
# impossibilitou_pagamento         autonomo_reducao_renda                                          NaN
#                                  desemprego_familia                                              NaN
#                                  despesa_aumentou                                                NaN
#                                  despesa_extraordinaria                                          NaN
#                                  despesa_saude                                                   NaN
#                                  emprestei_nome_terceiros                                        NaN
#                                  esquecimento                                                    NaN
#                                  salario_atrasado                                                NaN
# inadimplente_no_produto          carne_boleto                                                    NaN
#                                  cartao_credito                                                  NaN
#                                  cartao_loja                                                     NaN
#                                  cheque_devolvido                                                NaN
#                                  cheque_especial                                                 NaN
#                                  emprestimo_com_garantia                                         NaN
#                                  emprestimo_pessoal                                              NaN
# origem_dinheiro_pagamento_contas cobro_divida_de_terceiros                                       NaN
#                                  empresto_de_parentes                                            NaN
#                                  outros                                                        1.000
#                                  reduzo_custo                                                    NaN
#                                  renda_extra                                                     NaN
#                                  salario                                                         NaN
#                                  uso_dinheiro_extra                                              NaN
#                                  vender_bens                                                     NaN
#                                  vender_ferias                                                   NaN
# tendencias                       faco_compras_online                                             NaN
#                                  possuo_redes_sociais                                            NaN
#                                  possuo_servico_streaming                                        NaN
#                                  uso_delivery                                                    NaN
#                                  uso_sites_apostas                                               NaN
# All                                                                                            1.000
#
# valor                                                                                 All
# categoria                        rank
# fator_mudar_banco                Credito_aprovado_com_maior_agilidade                1393
#                                  Maior_limite_de_credito_rotativo                    1393
#                                  Maior_limite_para_financiamento                     1393
#                                  Maior_prazo_ou_parcelas_mais_baratas_para_finan...  1393
#                                  Nada                                                1393
#                                  Outros                                              1393
#                                  Taxas_menores_para_financiamento                    1393
# gerou_inadimplencia              agua_luz                                             742
#                                  aluguel_condominio                                   742
#                                  educacao                                             742
#                                  material_construcao                                  742
#                                  moveis_e_eletro                                      742
#                                  saude                                                742
#                                  supermercado_alimentacao                             742
#                                  tv_internet_telefone                                 742
#                                  vestuario_calcados                                   742
#                                  viagens                                              742
# impossibilitou_pagamento         autonomo_reducao_renda                               742
#                                  desemprego_familia                                   742
#                                  despesa_aumentou                                     742
#                                  despesa_extraordinaria                               742
#                                  despesa_saude                                        742
#                                  emprestei_nome_terceiros                             742
#                                  esquecimento                                         742
#                                  salario_atrasado                                     742
# inadimplente_no_produto          carne_boleto                                         742
#                                  cartao_credito                                       742
#                                  cartao_loja                                          742
#                                  cheque_devolvido                                     742
#                                  cheque_especial                                      742
#                                  emprestimo_com_garantia                              742
#                                  emprestimo_pessoal                                   742
# origem_dinheiro_pagamento_contas cobro_divida_de_terceiros                           1600
#                                  empresto_de_parentes                                1600
#                                  outros                                                41
#                                  reduzo_custo                                        1600
#                                  renda_extra                                         1600
#                                  salario                                             1600
#                                  uso_dinheiro_extra                                  1600
#                                  vender_bens                                         1600
#                                  vender_ferias                                       1600
# tendencias                       faco_compras_online                                 1393
#                                  possuo_redes_sociais                                1393
#                                  possuo_servico_streaming                            1393
#                                  uso_delivery                                        1393
#                                  uso_sites_apostas                                   1393
# All                                                                                  1600
#
# [47 rows x 40 columns]

# %%
np.sort(df_pesquisa['QSPRINCIPAL'].unique())
# Out:
# array([201, 202, 203, 204, 205, 206, 208, 210, 211, 212, 216, 217, 218,
#        219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 230, 971, 972,
#        973])

# %%
df_pesquisa['QSPRINCIPAL'].value_counts()
# Out:
# QSPRINCIPAL
# 222    301
# 217    192
# 206    176
# 203    173
# 211    169
# 226    141
# 971    114
# 216     78
# 973     41
# 219     39
# 224     36
# 223     30
# 210     25
# 972     21
# 228     11
# 221      9
# 230      9
# 220      7
# 205      7
# 218      7
# 227      5
# 201      3
# 204      2
# 212      1
# 202      1
# 208      1
# 225      1
# Name: count, dtype: int64

# %%
df_transf2['tipo_emprego'].unique()
# Out:
# array(['Empregado tempo integral', 'Autonomo', 'Empregado tempo parcial',
#        'Cuido da casa', 'Estudante', 'Aposentado', 'Desempregado',
#        'Outros'], dtype=object)
